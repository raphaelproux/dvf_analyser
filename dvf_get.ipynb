# %%
import requests
import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
r = requests.get(r'http://api.cquest.org/dvf?code_commune=35238&nature_mutation=Vente&type_local=Maison')
data = json.loads(r.text)

# %%
list_transactions = pd.DataFrame(data["resultats"])
list_transactions.head
# Out:
# <bound method NDFrame.head of      code_service_ch reference_document articles_1 articles_2 articles_3  \
# 0               None               None       None       None       None
# 1               None               None       None       None       None
# 2               None               None       None       None       None
# 3               None               None       None       None       None
# 4               None               None       None       None       None
# ...              ...                ...        ...        ...        ...
# 2439            None               None       None       None       None
# 2440            None               None       None       None       None
# 2441            None               None       None       None       None
# 2442            None               None       None       None       None
# 2443            None               None       None       None       None
#
# ...

# %%
list_transactions["date_mutation"]
# Out:
# 0       2017-03-17
# 1       2018-08-21
# 2       2016-10-18
# 3       2014-07-21
# 4       2014-10-20
#            ...
# 2439    2019-03-18
# 2440    2016-11-10
# 2441    2016-12-12
# 2442    2016-12-16
# 2443    2016-12-29
# Name: date_mutation, Length: 2444, dtype: object
