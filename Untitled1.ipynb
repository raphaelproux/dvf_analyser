# %%
import re
import numpy as np
from decimal import Decimal, InvalidOperation

import requests
from bs4 import BeautifulSoup

# %%
list_sites = {
    'guenno': {
        'url': 'https://www.guenno.com/biens/recherche?realty_type%5B%5D=2&mandate_type=1&min_surface=&town=acigne&price_max=',
    }
}

# %%
houses = []

for site_name, site_info in list_sites.items():
    print(f'Site: {site_name}')
    r = requests.get(site_info['url'])
    soup = BeautifulSoup(r.text, "lxml")

    house_list = soup.find(id="listRealtys").find_all("article")

    for house in house_list:
        title = house.find(attrs={'class': "article-title"}).text
        details = f"{house.find(attrs={'class': 'detail'}).text} {house.find(attrs={'class': 'more-about-realty'}).text}"
        details = re.sub(r'\n\s*| +', ' ', details)
        price = house.find(attrs={'class': "realty_price"}).text
        price = re.sub(r' *|€', '', price)
        price = re.sub(r',', '.', price)
        try:
            price = Decimal(price)
        except InvalidOperation:
            price = np.nan
        houses.append({
            "title": title,
            "details": details,
            "price": price
        })

        print(title, details, price)
# Out:
# Site: guenno
# ACIGNE / centre-ville Achat /Maison, 4 chambres  Les + du bien :  emplacement - qualité prestation - façade pierre - exposition - chambre au rdc - charme de l'ancien - garage type Hangard  nan
# ACIGNE / CAMPAGNE Achat /Maison, 4 chambres  Les + du bien :  BIEN VENDU PAS DE VISITE SVP !!!!!!!!!!ANNONCE POUR PUBLICATION LBC  nan
# Acigné / Centre Achat /Maison, 4 chambres  Les + du bien :  emplacement - bien renovée - expo traversante _ lumineuse - chambre et salle d'eau au RDC - cuisine top - prestation de qualité - ravalement recent  nan
# ACIGNE / CENTRE VILLE Achat /Maison, 2 chambres  Les + du bien :  Emplacement numéro 1 - Exposition - Jardin - Beau potentiel - Huisseries neuves avec volets électriques - sous-sol complet - proche commerces et écoles  242490
# ACIGNE / campagne Achat /Maison, 3 chambres  Les + du bien :  Maison Vendue  263495
# ACIGNE / CENTRE BOURG Achat /Maison, 5 chambres  Les + du bien :  Emplacement - surface terrain - double vitrage - beau garage avec atelier - chambre en rez-de-chaussée - aucun vis à vis - en impasse  305490
# ACIGNE / ACIGNE Achat /Maison, 4 chambres  Les + du bien :  Lumineux - Belle pièce de vie - récent - proche transport - bon état  327495
# ACIGNE / CENTRE VILLE Achat /Maison, 3 chambres  Les + du bien :  MAISON RENOVEE - QUARTIER CALME A PROXIMITE DU CENTRE VILLE - LUMINEUSE - BEAU JARDIN  348490
# ACIGNE / centre-ville Achat /Maison, 4 chambres  Les + du bien :  MAISON RENOVEE - NON MITOYENNE - QUARTIER CALME A PROXIMITE DU CENTRE VILLE - LUMINEUSE - BEAU JARDIN  348490
# ACIGNE / CENTRE VILLE Achat /Maison, 4 chambres  Les + du bien :  MAISON LUMINEUSE - EN IMPASSE - QUARTIER CALME - PROCHE DU CENTRE VILLE DES ECOLES ET DES COMMERCES - BEAUX VOLUMES - MAGNIFIQUE TERRAIN SANS VIS A VIS  348490
